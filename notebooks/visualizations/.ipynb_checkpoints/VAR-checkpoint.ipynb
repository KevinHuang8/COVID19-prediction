# %%
import sys
sys.path.append('../')
import xgboost as xgb
import numpy as np
import importlib
import utils as u
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd
importlib.reload(u)
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

# %%
datadict = u.load_covid_timeseries(smoothing=3, cases_cutoff=100)
cases = datadict['cases_calibrated']
deaths = datadict['deaths_calibrated']

# %%
def transform(x):
    x0 = np.expand_dims(x[:, 0], axis=1)
    t = np.diff(x)
    t0 = np.expand_dims(t[:, 0], axis=1)
    t = np.diff(t)
    return t, t0, x0

# %%
def untransform(t, t0, x0, a=1):
    x = np.hstack([t0, t])
    x = np.cumsum(x, axis=a)
    x = np.hstack([x0, x])
    x = np.cumsum(x, axis=a)
    return x

# %%
deaths2, dt0, dx0 = transform(deaths)
cases2, ct0, cx0 = transform(cases)
d_orig = untransform(deaths2, dt0, dx0)

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

#     Print Summary
#     print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
#     print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
#     print(f' Significance Level    = {signif}')
#     print(f' Test Statistic        = {output["test_statistic"]}')
#     print(f' No. Lags Chosen       = {output["n_lags"]}')

#     for key,val in r[4].items():
#         print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")    
    return p_value

# %%
pvals = []
for i, s in enumerate(deaths2):
    if np.all(np.isnan(s)):
        continue
    p = adfuller_test(pd.Series(s).fillna(0))
    pvals.append(p)
    print('\n')
# Out:
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0026. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0004. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.124. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0007. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.3068. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.6375. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0059. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0137. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0118. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.2866. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0032. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.1652. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0156. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0689. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0003. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0968. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0065. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0014. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0003. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0002. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0862. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0004. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0007. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.1453. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0212. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.161. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.01. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0012. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0003. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0249. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.1342. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0083. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0008. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0178. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0411. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.01. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.1159. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0005. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0103. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.2713. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0145. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.1285. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0968. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0041. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0635. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0127. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.1083. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0046. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0589. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.2834. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.648. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.3676. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0198. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0305. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0004. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0147. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0323. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.353. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0002. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0079. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0204. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0017. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.046. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.21. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0094. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0686. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.1043. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.3902. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.2799. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.1204. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.1069. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.003. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.4127. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0068. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.2144. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0814. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0008. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0866. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0546. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.1207. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0002. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0023. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.1034. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0021. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0007. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.415. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0532. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0012. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0501. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0018. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0003. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.7167. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.1271. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0317. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.005. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.198. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0031. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0017. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0002. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0083. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0028. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0188. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0005. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0148. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0018. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0016. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  => P-Value = nan. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %%
d = cases2
x1 = np.linspace(1, d.shape[1], d.shape[1])
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
plt.plot(x1, d[1868])
print(d.shape)
plt.show()
# Out:
# (3142, 93)

# %%
county = 1868
X = np.vstack([cases2[county], deaths2[county]])
s = np.argmax(np.isnan(X))
X = X[:, :s]

# %%
X_train = X[:, :30].astype(int)
X_test = X[:, 30:].astype(int)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (2, 30) (2, 9)

# %%
model = VAR(X_train.T)
for i in range(20):
    result = model.fit(i)
    print('Lag Order =', i)
    print('AIC : ', result.aic)
    print('BIC : ', result.bic)
    print('FPE : ', result.fpe)
    print('HQIC: ', result.hqic, '\n')
# Out:
# Lag Order = 0
# AIC :  22.280524571139587
# BIC :  22.373937729917063
# FPE :  4746028437.374994
# HQIC:  22.310408243233127
#
# Lag Order = 1
# AIC :  20.8756536886153
# BIC :  21.158542481026295
# FPE :  1166343309.094579
# HQIC:  20.964250929131097
#
# Lag Order = 2
# AIC :  20.80740283867131
# BIC :  21.283190163733885
# FPE :  1096231050.1775491
# HQIC:  20.95285576726036
#
# Lag Order = 3
# AIC :  20.917592785295916
# BIC :  21.58950819729816
# FPE :  1244266765.9838977
# HQIC:  21.117388461443124
#
# Lag Order = 4
# AIC :  21.10297864457615
# BIC :  21.9739685555141
# FPE :  1551724445.3228152
# HQIC:  21.353792224158475
#
# Lag Order = 5
# AIC :  21.158601764714792
# BIC :  22.231212490598807
# FPE :  1758144770.5574863
# HQIC:  21.456098394276008
#
# Lag Order = 6
# AIC :  21.492927471354804
# BIC :  22.769152454231744
# FPE :  2798378794.2283554
# HQIC:  21.831510318568988
#
# Lag Order = 7
# AIC :  21.624097977789543
# BIC :  23.10517738987104
# FPE :  4089512315.8317103
# HQIC:  21.99658529855851
#
# Lag Order = 8
# AIC :  21.280222274936335
# BIC :  22.966378793762825
# FPE :  4827336249.88064
# HQIC:  21.677430049218106
#
# Lag Order = 9
# AIC :  13.414471617214987
# BIC :  15.304559837857372
# FPE :  7180564.400703633
# HQIC:  13.824669145832077
#
# Lag Order = 10
# AIC :  -105.59132589623832
# BIC :  -103.50028812177494
# FPE :  3.497846249859228e-45
# HQIC:  -105.18313335470553
#
# Lag Order = 11
# AIC :  -106.19703671480133
# BIC :  -103.91050023892468
# FPE :  6.587065194689614e-47
# HQIC:  -105.81006389606281
#
# Lag Order = 12
# AIC :  -106.7182044878047
# BIC :  -104.2449496047598
# FPE :  6.559434228823358e-48
# HQIC:  -106.3771759889065
#
# Lag Order = 13
# AIC :  -108.01335681698225
# BIC :  -105.36667913586251
# FPE :  4.1519605530328464e-49
# HQIC:  -107.75027183606012
#
# Lag Order = 14
# AIC :  -107.86803811289093
# BIC :  -105.06740399477172
# FPE :  1.2117404425916494e-49
# HQIC:  -107.72462266898879
#
# Lag Order = 15
# AIC :  -106.26327617409335
# BIC :  -103.33666867620421
# FPE :  1.5050589463545947e-49
# HQIC:  -106.29445065902848
#
# Lag Order = 16
# AIC :  -105.01046876758818
# BIC :  -101.9977699279734
# FPE :  1.2202388345814547e-49
# HQIC:  -105.28934911554445
#
# Lag Order = 17
# AIC :  -104.03033748759292
# BIC :  -100.98830248587696
# FPE :  6.619391901681819e-50
# HQIC:  -104.65561265184404
#
# Lag Order = 18
# AIC :  -102.2557572467604
# BIC :  -99.26549957306773
# FPE :  6.593293632137651e-50
# HQIC:  -103.36285776192138
#
# Lag Order = 19
# AIC :  -99.16351020078227
# BIC :  -96.34207099366655
# FPE :  1.898336857369631e-49
# HQIC:  -100.94203240659178

# %%
model_fitted = model.fit(5)
model_fitted.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 26, Apr, 2020
# Time:                     21:43:55
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    22.2312
# Nobs:                     25.0000    HQIC:                   21.4561
# Log likelihood:          -313.429    FPE:                1.75814e+09
# AIC:                      21.1586    Det(Omega_mle):     8.47871e+08
# --------------------------------------------------------------------
# Results for equation y1
# ========================================================================
#            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------
# const        27.650324       155.309678            0.178           0.859
# L1.y1        -0.948435         0.267167           -3.550           0.000
# L1.y2         1.112966         2.167413            0.514           0.608
# L2.y1        -0.655785         0.370476           -1.770           0.077
# L2.y2         2.099221         3.748888            0.560           0.576
# L3.y1        -0.341884         0.424577           -0.805           0.421
# L3.y2         1.393035         4.084160            0.341           0.733
# L4.y1         0.080447         0.421802            0.191           0.849
# L4.y2        -0.072202         3.971392           -0.018           0.985
# L5.y1         0.283415         0.291881            0.971           0.332
# L5.y2         0.545590         2.632893            0.207           0.836
# ========================================================================
#
# Results for equation y2
# ========================================================================
#            coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------
# const        16.843214        17.551307            0.960           0.337
# L1.y1         0.001349         0.030192            0.045           0.964
# L1.y2        -1.341822         0.244936           -5.478           0.000
# L2.y1        -0.030804         0.041867           -0.736           0.462
# L2.y2        -0.705231         0.423656           -1.665           0.096
# L3.y1        -0.028870         0.047981           -0.602           0.547
# L3.y2        -0.325524         0.461545           -0.705           0.481
# L4.y1         0.010486         0.047667            0.220           0.826
# L4.y2         0.363867         0.448801            0.811           0.418
# L5.y1         0.019430         0.032985            0.589           0.556
# L5.y2         0.682882         0.297539            2.295           0.022
# ========================================================================
#
# Correlation matrix of residuals
#             y1        y2
# y1    1.000000  0.099240
# y2    0.099240  1.000000

# %%
forecast_input = X_train[-9:].T
fc = model_fitted.forecast(y=forecast_input, steps=14)

# %%
fc = fc.astype(int)
fc
# Out:
# array([[ 255,   41],
#        [-547,  -57],
#        [ 751,  252],
#        [-122, -372],
#        [-286,  334],
#        [ 119, -263],
#        [-109,  317],
#        [ 785, -277],
#        [-981,  114],
#        [ 596,   61],
#        [-382, -111],
#        [ 725,  216],
#        [-536, -362],
#        [ -85,  462]])

# %%
forecast_input
# Out:
# array([[  155,     0],
#        [  224,     0],
#        [ -145,     0],
#        [  484,     0],
#        [ -387,    21],
#        [  445,    -2],
#        [ -163,     1],
#        [ 1313,    12],
#        [-1114,     0],
#        [  -90,    -7],
#        [  765,    42],
#        [ -711,   -30],
#        [ 1113,    15],
#        [ -906,    19],
#        [  235,     0],
#        [  254,   -19],
#        [  402,    39],
#        [ -713,     4],
#        [   31,    33],
#        [  375,     7],
#        [   10,    46],
#        [ -299,    34],
#        [   96,  -159],
#        [   47,   303],
#        [  437,  -270],
#        [ -444,   179],
#        [ -394,  -268],
#        [  -82,   305],
#        [  644,  -122],
#        [ -559,   -33]])

# %%
predictions = np.vstack([forecast_input, fc]).T
cases_predictions = predictions[0]
deaths_predictions = predictions[1]

# %%
cases_predictions = untransform(cases_predictions, ct0[county], cx0[county], 0)
deaths_predictions = untransform(deaths_predictions, dt0[county], dx0[county], 0)

# %%
d = deaths_predictions
x1 = np.linspace(1, d.shape[0], d.shape[0])
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111)
plt.plot(x1, d)
d2 = deaths[county]
x2 = np.linspace(1, d2.shape[0], d2.shape[0])
plt.plot(x2, d2)
print(d.shape)
plt.show()
# Out:
# (46,)
